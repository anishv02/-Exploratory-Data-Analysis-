# %% [markdown]
# <a href="https://colab.research.google.com/github/anishv02/-Exploratory-Data-Analysis-/blob/main/Anishv_Rawal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# **Anishv Rawal**

# %% [markdown]
# **TASK** - **Salary Prediction**
#
# ---

# %% [markdown]
# **Concept Used** =  Implimenting regression functions with the help of python Skit-Learn library

# %%
#importing all libraries required in this notebook
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
print('Setup Complete')

# %%
#reading data from given dataset
data = pd.read_csv('https://raw.githubusercontent.com/CSCult/salary-prediction/main/Salary_Data.csv')
data.head()

# %%
data.describe()

# %%
data.shape

# %% [markdown]
# **Analyzing the data**
#
# Let's plot our data points on 2-D graph to eyeball our dataset and see if we can manually find any relationship between the data. We can create the plot with the following script:

# %%
data.plot(x= 'YearsExperience', y = 'Salary', style = 'o')
plt.title('Experience VS Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# **From the graph above, we can clearly see that there is a positive linear relation between the years of experience and salary.**
#
# Preparing the data
#
# The next step is to divide the data into "attributes" (inputs) and "labels" (outputs).

# %%
# Data Processing
X=data.iloc[: , : -1].values
Y=data.iloc[: , 1].values

# %% [markdown]
# Now that we have our attributes and labels, the next step is to split this data into training and test sets. We'll do this by using Scikit-Learn's built-in train_test_split() method:

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.3,random_state = 0)

# %% [markdown]
# Now it's time for the final step
#
# Training the Algorithm, We have split our data into training and testing sets, and now is finally the time to train our algorithm.

# %%
regressor  = LinearRegression()
regressor.fit(X_train,Y_train)
print('Training Complete')

# %%
# Plotting the regression line
line = regressor.coef_*X+regressor.intercept_

# Plotting for the test data
plt.scatter(X,Y)
plt.plot(X, line);
plt.show()

# %% [markdown]
# Making Predictions
#
# Now that we have trained our algorithm, it's time to make some predictions.

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# Now comparing the actual and predicted data.

# %%
cmp = pd.DataFrame({'Actual' : Y_test, 'Predicted' : y_pred})
cmp

# %%
train = regressor.score(X_train,Y_train)
test = regressor.score(X_test,Y_test)

# %% [markdown]
# Hence by the above testing of the dataset we have the predicting and testing scores and they are as follows:

# %%
print('Testing Scores: ', test)
print('Training Scores', train)
